# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', None)

# %%
credit_card = pd.read_csv("UCI_Credit_Card.csv")
credit_card.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit_card.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
credit_card.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit_card.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
credit_card.shape
# Out:
# (30000, 25)

# %%
credit_card["EDUCATION"].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %%
credit_card["MARRIAGE"].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
credit_card = credit_card.rename(columns = {"default.payment.next.month" : 'def_pay',
                                           "PAY_0" : "PAY_1"})

# %%
credit_card.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
plt.subplots(figsize = (20,20))
sns.heatmap(credit_card.corr(), annot = True)
# Out:
# <Axes: >

# %%
credit_card.corr().T
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
X = credit_card[["LIMIT_BAL", "PAY_1", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6"]]
y = credit_card["def_pay"]

# %%
X["PAY_3"].value_counts()
# Out:
#  0    15764
# -1     5938
# -2     4085
#  2     3819
#  3      240
#  4       76
#  7       27
#  6       23
#  5       21
#  1        4
#  8        3
# Name: PAY_3, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

# %%
rfc.score(X_test, y_test)
# Out:
# 0.8032222222222222

# %%
def replace_to_zero(col):
    fil = (credit_card[col] == -2) | (credit_card[col] == -1) | (credit_card[col] == 0)
    credit_card.loc[fil, col] = 0

for i in ['PAY_1','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']:
    replace_to_zero(i)

# %%
credit_card["PAY_1"].value_counts()
# Out:
# 0    23182
# 1     3688
# 2     2667
# 3      322
# 4       76
# 5       26
# 8       19
# 6       11
# 7        9
# Name: PAY_1, dtype: int64

# %%
credit_card.corr()
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX        0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION  0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE  -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
# AGE        0.018678   0.144713 -0.090874   0.175061 -0.414170  1.000000
# PAY_1     -0.020978  -0.170745 -0.034475   0.050180 -0.011724 -0.001447
# PAY_2     -0.010001  -0.197136 -0.044750   0.055610 -0.009915 -0.008774
# PAY_3     -0.018820  -0.191323 -0.041227   0.045278  0.000717 -0.014266
# PAY_4      0.013700  -0.180629 -0.039737   0.044117 -0.004039 -0.007288
# PAY_5     -0.020336  -0.170045 -0.038533   0.033551 -0.002772 -0.013277
# PAY_6     -0.032450  -0.167820 -0.032061   0.023124  0.002050 -0.016948
# ...

# %%
plt.subplots(figsize = (20,20))
sns.heatmap(credit_card.corr(), annot = True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(X_test, y_test)
# Out:
# 0.8041666666666667

# %%
def get_age_group(age):
    if age < 25:
        return 1;
    elif age < 30:
        return 2;
    elif age < 35:
        return 3;
    elif age < 40:
        return 4;
    elif age < 45:
        return 5;
    elif age < 50:
        return 6;
    elif age < 60:
        return 7;
    elif age < 70:
        return 8;
    else:
        return 9;

# %%
credit_card["AgeGroup"]=credit_card["AGE"].apply(get_age_group)

# %%
credit_card.corr()
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX        0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION  0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE  -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
# AGE        0.018678   0.144713 -0.090874   0.175061 -0.414170  1.000000
# PAY_1     -0.020978  -0.170745 -0.034475   0.050180 -0.011724 -0.001447
# PAY_2     -0.010001  -0.197136 -0.044750   0.055610 -0.009915 -0.008774
# PAY_3     -0.018820  -0.191323 -0.041227   0.045278  0.000717 -0.014266
# PAY_4      0.013700  -0.180629 -0.039737   0.044117 -0.004039 -0.007288
# PAY_5     -0.020336  -0.170045 -0.038533   0.033551 -0.002772 -0.013277
# PAY_6     -0.032450  -0.167820 -0.032061   0.023124  0.002050 -0.016948
# ...

# %%
credit_card["EDUCATION"].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %%
f = (credit_card["EDUCATION"] == 0) | (credit_card["EDUCATION"] == 5) | (credit_card["EDUCATION"] == 6)
credit_card.loc[f, 'EDUCATION'] = 4
credit_card["EDUCATION"].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %%
credit_card["MARRIAGE"].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
mar = (credit_card["MARRIAGE"] == 0)
credit_card.loc[mar, "MARRIAGE"] = 3
credit_card["MARRIAGE"].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %%
credit_card.corr()
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.037659 -0.028208  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.231088 -0.111012  0.144713
# SEX        0.018497   0.024755  1.000000   0.013627 -0.028522 -0.090874
# EDUCATION  0.037659  -0.231088  0.013627   1.000000 -0.136797  0.182434
# MARRIAGE  -0.028208  -0.111012 -0.028522  -0.136797  1.000000 -0.412001
# AGE        0.018678   0.144713 -0.090874   0.182434 -0.412001  1.000000
# PAY_1     -0.020978  -0.170745 -0.034475   0.055937 -0.011551 -0.001447
# PAY_2     -0.010001  -0.197136 -0.044750   0.062739 -0.009275 -0.008774
# PAY_3     -0.018820  -0.191323 -0.041227   0.053058  0.002556 -0.014266
# PAY_4      0.013700  -0.180629 -0.039737   0.051209 -0.003029 -0.007288
# PAY_5     -0.020336  -0.170045 -0.038533   0.039623 -0.002497 -0.013277
# PAY_6     -0.032450  -0.167820 -0.032061   0.028670  0.002793 -0.016948
# ...

# %%
X_features = credit_card.loc[:, credit_card.columns != "def_pay"]
X_features
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2      0
# 1          2   120000.0    2          2         2   26      0      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43      0      0      0
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1      0      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.3, stratify = y)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(X_test, y_test)
# Out:
# 0.8193333333333334

# %% [markdown]
# ## EDA

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "def_pay", data = credit_card)
# Out:
# <Axes: xlabel='def_pay', ylabel='count'>

# %%
credit_card["def_pay"].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: def_pay, dtype: int64

# %% [markdown]
# default have imbalanced dataset.

# %% [markdown]
# ## Independent variables
# ### Categorical Features
# 1. SEX
# 2. EDUCATION
# 3. MARRIAGE

# %%
categorical_features = ["SEX", "EDUCATION", "MARRIAGE"] 
card_cat = credit_card[categorical_features]
card_cat["def_pay"] = credit_card["def_pay"]
# Out:
# C:\Users\Gavi\AppData\Local\Temp\ipykernel_6732\1475795593.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   card_cat["def_pay"] = credit_card["def_pay"]

# %%
for col in categorical_features:
    plt.figure(figsize=(10,5))
    fig, axes = plt.subplots(ncols=2, figsize=(13,8))
    credit_card[col].value_counts().plot(kind = "pie", ax = axes[0], subplots = True)
    
    sns.countplot(x = col, hue = "def_pay", data = card_cat)

# %% [markdown]
# ### Age

# %%
sns.barplot(x = 'def_pay', y = 'LIMIT_BAL', data = credit_card)
# Out:
# <Axes: xlabel='def_pay', ylabel='LIMIT_BAL'>

# %%
fig, axes = plt.subplots(ncols = 2, figsize = (20,10))
day_card = credit_card["AGE"].value_counts().reset_index()
credit_card["AGE"].value_counts().plot(kind = "pie", ax = axes[0], subplots = True)
sns.barplot(x = "index", y = "AGE", data = day_card, ax = axes[1], orient = 'v')
# Out:
# <Axes: xlabel='index', ylabel='AGE'>

# %%
credit_card.groupby('def_pay')["AGE"].mean()
# Out:
# def_pay
# 0    35.417266
# 1    35.725738
# Name: AGE, dtype: float64

# %%
# smote 
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote, y_smote = smote.fit_resample(credit_card.iloc[:, 0:-1], credit_card["def_pay"])

print("Original dataset shape", len(credit_card))
print("Resampled dataset shape", len(y_smote))
# Out:
# Original dataset shape 30000
# Resampled dataset shape 46728

# %%
len(y_smote)
# Out:
# 46728

# %%
y_smote
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 46723    1
# 46724    1
# 46725    1
# 46726    1
# 46727    1
# Name: def_pay, Length: 46728, dtype: int64

# %%
X_smote
# Out:
#           ID      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0          1   20000.000000    2          2         1   24      2      2
# 1          2  120000.000000    2          2         2   26      0      2
# 2          3   90000.000000    2          2         2   34      0      0
# 3          4   50000.000000    2          2         1   37      0      0
# 4          5   50000.000000    1          2         1   57      0      0
# ...      ...            ...  ...        ...       ...  ...    ...    ...
# 46723  24724  100000.000000    2          2         2   25      1      2
# 46724   5197  184698.337892    2          2         1   37      1      0
# 46725  12034  230000.000000    1          1         1   42      0      0
# 46726   1237   60000.000000    1          1         2   27      0      0
# 46727  24085   20000.000000    1          2         1   33      0      0
#
#        PAY_3  PAY_4  PAY_5  PAY_6      BILL_AMT1     BILL_AMT2     BILL_AMT3  \
# ...

# %%
columns = list(credit_card.columns)
columns.pop(-1)
# Out:
# 'def_pay'

# %%
balanced_df = pd.DataFrame(X_smote, columns = columns )
balanced_df['def_pay'] = y_smote

# %%
balanced_df[balanced_df["def_pay"] == 1]
# Out:
#           ID      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0          1   20000.000000    2          2         1   24      2      2
# 1          2  120000.000000    2          2         2   26      0      2
# 13        14   70000.000000    1          2         2   30      1      2
# 16        17   20000.000000    1          1         2   24      0      0
# 21        22  120000.000000    2          2         1   39      0      0
# ...      ...            ...  ...        ...       ...  ...    ...    ...
# 46723  24724  100000.000000    2          2         2   25      1      2
# 46724   5197  184698.337892    2          2         1   37      1      0
# 46725  12034  230000.000000    1          1         1   42      0      0
# 46726   1237   60000.000000    1          1         2   27      0      0
# 46727  24085   20000.000000    1          2         1   33      0      0
#
#        PAY_3  PAY_4  PAY_5  PAY_6      BILL_AMT1     BILL_AMT2     BILL_AMT3  \
# ...

# %%
df_fr = balanced_df.copy()

# %%
df_log_reg = df_fr

# %%
X = df_log_reg.drop(["def_pay"], axis = 1)
y = df_log_reg["def_pay"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify= y )

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

param_grid = {'penalty':['l1','l2'], 'C' : [0.001, 0.01, 0.1, 1, 10, 100, 1000] }

grid = GridSearchCV(LogisticRegression(), param_grid, scoring='accuracy', 
                    n_jobs = -1, verbose = 3, cv = 3)
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# C:\Users\Gavi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 21 fits failed out of a total of 42.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 21 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Gavi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Gavi\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
optimized_clf = grid.best_estimator_

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l2'}

# %%
grid.best_score_
# Out:
# 0.6161606897184262

# %%
grid.score
# Out:
# <bound method BaseSearchCV.score of GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2']},
#              scoring='accuracy', verbose=3)>

# %%
train_preds = optimized_clf.predict_proba(X_train)[:,1]
test_preds = optimized_clf.predict_proba(X_test)[:,1]

# %%
train_class_preds = optimized_clf.predict(X_train)
test_class_preds = optimized_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc

# %%
train_accuracy_lr = accuracy_score(train_class_preds,y_train)
test_accuracy_lr = accuracy_score(test_class_preds,y_test)

print("The accuracy on train data is ", train_accuracy_lr)
print("The accuracy on test data is ", test_accuracy_lr)
# Out:
# The accuracy on train data is  0.6156103824635422
# The accuracy on test data is  0.6106712318995648
